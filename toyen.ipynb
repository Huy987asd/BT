# %% [markdown]
# <a href="https://colab.research.google.com/github/Huy987asd/BT/blob/main/toyen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# !unzip /content/drive/'My Drive'/ML/darknet.zip
# %cd /content/darknet
# Out:
# /content
# Archive:  /content/drive/My Drive/ML/darknet.zip
#    creating: darknet/.git/
#   inflating: darknet/.git/config
#   inflating: darknet/.git/description
#  extracting: darknet/.git/HEAD
#    creating: darknet/.git/hooks/
#   inflating: darknet/.git/hooks/applypatch-msg.sample
#   inflating: darknet/.git/hooks/commit-msg.sample
#   inflating: darknet/.git/hooks/fsmonitor-watchman.sample
#   inflating: darknet/.git/hooks/post-update.sample
#   inflating: darknet/.git/hooks/pre-applypatch.sample
#   inflating: darknet/.git/hooks/pre-commit.sample
#   inflating: darknet/.git/hooks/pre-merge-commit.sample
#   inflating: darknet/.git/hooks/prepare-commit-msg.sample
#   inflating: darknet/.git/hooks/pre-push.sample
#   inflating: darknet/.git/hooks/pre-rebase.sample
#   inflating: darknet/.git/hooks/pre-receive.sample
#   inflating: darknet/.git/hooks/push-to-checkout.sample
#   inflating: darknet/.git/hooks/update.sample
#   inflating: darknet/.git/index
# ...

# %%
# !make
# !chmod +x ./darknet
# Out:
# make: Warning: File 'Makefile' has modification time 1861 s in the future
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -c ./src/gemm.c -o obj/gemm.o
# Package opencv was not found in the pkg-config search path.
# Perhaps you should add the directory containing `opencv.pc'
# to the PKG_CONFIG_PATH environment variable
# No package 'opencv' found
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#   232 |         cudaThreadSynchronize();
#       |         ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/include/cuda_runtime.h:96,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# ...

# %%
# !rm /content/darknet/backup -r
# !ln -s /content/drive/'My Drive'/ML/backup /content/darknet

# %%
ls
# Out:
# backup@            include/      LICENSE.meta  python/    train.txt
# cfg/               LICENSE       LICENSE.mit   README.md  val.txt
# darknet53.conv.74  LICENSE.fuck  LICENSE.v1    results/   yolo.data
# data/              LICENSE.gen   Makefile      scripts/   yolo.names
# examples/          LICENSE.gpl   obj/          src/

# %%
ls -l
# Out:
# total 158808
# lrwxrwxrwx 1 root root        33 May 23 00:41 backup -> '/content/drive/My Drive/ML/backup'
# drwxr-xr-x 2 root root      4096 May 23  2023 cfg/
# -rw-r--r-- 1 root root 162482580 May 23  2023 darknet53.conv.74
# drwxr-xr-x 4 root root      4096 May 23  2023 data/
# drwxr-xr-x 2 root root      4096 May 23  2023 examples/
# drwxr-xr-x 2 root root      4096 May 23  2023 include/
# -rw-r--r-- 1 root root       527 May 23  2023 LICENSE
# -rw-r--r-- 1 root root       487 May 23  2023 LICENSE.fuck
# -rw-r--r-- 1 root root      6743 May 23  2023 LICENSE.gen
# -rw-r--r-- 1 root root     35815 May 23  2023 LICENSE.gpl
# -rw-r--r-- 1 root root       368 May 23  2023 LICENSE.meta
# -rw-r--r-- 1 root root      1093 May 23  2023 LICENSE.mit
# -rw-r--r-- 1 root root       474 May 23  2023 LICENSE.v1
# -rw-r--r-- 1 root root      3145 May 23  2023 Makefile
# drwxr-xr-x 2 root root      4096 May 23 00:40 obj/
# drwxr-xr-x 2 root root      4096 May 23  2023 python/
# ...

# %%
# %cd /content/darknet
# !./darknet detector train yolo.data cfg/yolov3.cfg darknet53.conv.74
# Out:
# /content/darknet
# /bin/bash: ./darknet: No such file or directory
