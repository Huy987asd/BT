# %% [markdown]
# <a href="https://colab.research.google.com/github/Huy987asd/BT/blob/main/Thu7ngay8_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

folder = '/content/drive/MyDrive/huypro/'
for i in range(60):
  plt.subplot(10, 6, i+1)
  filename = folder + 'l'+str(i+1)+'.jpg'
  img = plt.imread(filename)
  plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-a168497cdda3> in <cell line: 5>()
#       6   plt.subplot(10, 6, i+1)
#       7   filename = folder + 'l'+str(i+1)+'.jpg'
# ----> 8   img = plt.imread(filename)
#       9   plt.imshow(img)
#      10 plt.show()
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in imread(fname, format)
#    2193 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2194 def imread(fname, format=None):
# -> 2195     return matplotlib.image.imread(fname, format)
#    2196
#    2197
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/image.py in imread(fname, format)
#    1561             "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1562             )
# -> 1563     with img_open(fname) as image:
#    1564         return (_pil_png_to_float_array(image)
# ...

# %%
from numpy.ma.core import asarray
from os import listdir
from numpy import asarray
from numpy import save
from keras.utils import load_img, img_to_array

folder = '/content/drive/MyDrive/huypro/'
photos, labels = list(), list()
for file in listdir(folder):
  output = 0.0
  if file.startswith('l'):
    output =1
  if file.startswith('Cuong'):
    output =2
  img = load_img(folder+file)
  photo =img_to_array(img)
  photos.append(photo)
  labels.append(output)

photos = asarray(photo)
labels = asarray(labels)
print(photos.shape, labels.shape)
save('/content/drive/MyDrive/huypro/', photos)
save('/content/drive/MyDrive/huypro/', labels)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-9-3cec01922f19> in <cell line: 9>()
#      13   if file.startswith('Cuong'):
#      14     output =2
# ---> 15   img = load_img(folder+file)
#      16   photo =img_to_array(img)
#      17   photos.append(photo)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     421             path = str(path.resolve())
#     422         with open(path, "rb") as f:
# --> 423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#     425         raise TypeError(
#
# /usr/local/lib/python3.9/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3028     for message in accept_warnings:
#    3029         warnings.warn(message)
# -> 3030     raise UnidentifiedImageError(
# ...

# %%
import pandas as pd
data=pd.read_csv(/content/drive/MyDrive/pima-indians-diabetes.csv)
data.head()
x=data.iloc[:,0:8]
y=data.iloc[0:8]
