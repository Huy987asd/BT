# %% [markdown]
# <a href="https://colab.research.google.com/github/Huy987asd/BT/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skfuzzy.control.state import StatePerSimulation
from skfuzzy.control.controlsystem import ControlSystem
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl 
time = ctrl.Antecedent(np.arange(0,181,1),'time')
rice = ctrl.Antecedent(np.arange(100,2001,1),'rice')
power = ctrl.Antecedent(np.arange(0,101,1),'power')
time['Verry Fast'] = fuzz.trimf(time.universe,[0,15,20])
time['Fast'] = fuzz.trimf(time.universe,[20,25,35])
time['Normal'] = fuzz.trimf(time.universe,[25,35,45])
time['Slow'] = fuzz.trimf(time.universe,[45,60,70])
time['Verry Slow'] = fuzz.trimf(time.universe,[70,120,180])
rice['VL'] = fuzz.trimf(rice.universe,[100,250,350])
rice['L'] = fuzz.trimf(rice.universe,[350,550,700])
rice['Normal'] = fuzz.trimf(rice.universe,[700,850,950])
rice['M'] = fuzz.trimf(rice.universe,[950,1200,1500])
rice['VM'] = fuzz.trimf(rice.universe,[1500,1800,2000])
power['low'] = fuzz.trimf(power.universe,[10,10,15])
power['medium'] = fuzz.trimf(power.universe,[15,20,30])
power['good'] = fuzz.trimf(power.universe,[20,30,30])
time.view()
rice.view()
power.view()

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 28.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=367adc51479ffc4e211e9a63456a6bf333c1ead9a583e9ff3c5135961041c269
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...
